# %% [markdown]
# # Preperation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import scipy.spatial
import warnings
import sklearn as sk

warnings.simplefilter("ignore")
# Enable inline mode for matplotlib so that Jupyter displays graphs
# %matplotlib inline

pd.__version__ #print which version of pandas you're using
# Out:
# '0.24.2'

# %% [markdown]
# ## read and combine files

# %%
h1b_17 = pd.read_csv('H-1B_2017.csv')
h1b_17.shape
# Out:
# (624650, 53)

# %%
h1b_17 = h1b_17.drop('Unnamed: 0',axis=1)
h1b_17.head()
# Out:
#           CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  I-200-16055-173457  CERTIFIED-WITHDRAWN     2016-02-24    2016-10-01
# 1  I-200-16064-557834  CERTIFIED-WITHDRAWN     2016-03-04    2016-10-01
# 2  I-200-16063-996093  CERTIFIED-WITHDRAWN     2016-03-10    2016-10-01
# 3  I-200-16272-196340            WITHDRAWN     2016-09-28    2016-10-01
# 4  I-200-15053-636744  CERTIFIED-WITHDRAWN     2015-02-22    2016-10-02
#
#   VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0       H-1B            2016-08-10          2019-08-10
# 1       H-1B            2016-08-16          2019-08-16
# 2       H-1B            2016-09-09          2019-09-09
# 3       H-1B            2017-01-26          2020-01-25
# 4       H-1B            2015-03-01          2018-03-01
#
#                EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0     DISCOVER PRODUCTS INC.                   NaN
# 1           DFS SERVICES LLC                   NaN
# 2  EASTBANC TECHNOLOGIES LLC                   NaN
# 3          INFO SERVICES LLC                   NaN
# 4           BB&T CORPORATION                   NaN
#
#              EMPLOYER_ADDRESS  ... H1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B  \
# 0         2500 LAKE COOK ROAD  ...             N                N         NaN
# 1         2500 LAKE COOK ROAD  ...             N                N         NaN
# 2            1211 31ST ST. NW  ...             Y                N           Y
# 3  17177 NORTH LAUREL PARK DR  ...             Y                N           Y
# 4        223 WEST NASH STREET  ...             N                N         NaN
#
#   LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION WORKSITE_CITY WORKSITE_COUNTY  \
# 0               Y                        NaN    RIVERWOODS            LAKE
# 1               Y                        NaN    RIVERWOODS            LAKE
# 2             NaN                        NaN    WASHINGTON             NaN
# 3             NaN                        NaN   JERSEY CITY          HUDSON
# 4               Y                        NaN      NEW YORK        NEW YORK
#
#   WORKSITE_STATE WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE
# 0             IL                60015         2016-03-01
# 1             IL                60015         2016-03-08
# 2             DC                20007         2016-03-16
# 3             NJ                07302                NaN
# 4             NY                10036         2015-02-26
#
# [5 rows x 52 columns]

# %%
h1b_18 = pd.read_csv('H-1B_2018.csv')
h1b_18.shape
# Out:
# (654360, 52)

# %%
h1b_18.rename(columns={'NEW_CONCURRENT_EMP': 'NEW_CONCURRENT_EMPLOYMENT'}, inplace=True)
h1b_18.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE VISA_CLASS  \
# 0  I-200-18026-338377   CERTIFIED        1/29/18        2/2/18       H-1B
# 1  I-200-17296-353451   CERTIFIED       10/23/17      10/27/17       H-1B
# 2  I-200-18242-524477   CERTIFIED        8/30/18        9/6/18       H-1B
# 3  I-200-18070-575236   CERTIFIED            NaN       3/30/18       H-1B
# 4  I-200-18243-850522   CERTIFIED        8/31/18        9/7/18       H-1B
#
#   EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE                EMPLOYER_NAME  \
# 0               7/28/18             7/27/21        MICROSOFT CORPORATION
# 1               11/6/17             11/6/20       ERNST & YOUNG U.S. LLP
# 2               9/10/18              9/9/21                 LOGIXHUB LLC
# 3               9/10/18              9/9/21  HEXAWARE TECHNOLOGIES, INC.
# 4                9/7/18              9/6/21             ECLOUD LABS,INC.
#
#   EMPLOYER_BUSINESS_DBA       EMPLOYER_ADDRESS  ... H1B_DEPENDENT  \
# 0                   NaN        1 MICROSOFT WAY  ...             N
# 1                   NaN        200 PLAZA DRIVE  ...             N
# 2                   NaN       320 DECKER DRIVE  ...             N
# 3                   NaN  101 WOOD AVENUE SOUTH  ...             Y
# 4                   NaN      120 S WOOD AVENUE  ...             Y
#
#   WILLFUL_VIOLATOR SUPPORT_H1B LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION  \
# 0                N         NaN             NaN                        NaN
# 1                N         NaN             NaN                        NaN
# 2                N         NaN             NaN                        NaN
# 3                N           Y             NaN                        NaN
# 4                N           Y               Y                        NaN
#
#   WORKSITE_CITY WORKSITE_COUNTY WORKSITE_STATE WORKSITE_POSTAL_CODE  \
# 0       REDMOND            KING             WA                98052
# 1   SANTA CLARA        SAN JOSE             CA                95110
# 2        IRVING          DALLAS             TX                75062
# 3    NEW CASTLE      NEW CASTLE             DE                19720
# 4    BIRMINGHAM          SHELBY             AL                35244
#
#   ORIGINAL_CERT_DATE
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ### deal with type issue on h1b_18

# %%
import decimal

def str_to_float(field, raw_data):
    wages = []
    for i,  r in h1b_18.iterrows():
        if type(r[field]) != float:
            wages.append(float(decimal.Decimal(r[field].replace(",",""))))
        else:
            wages.append(r[field])

    raw_data[field] = wages
    return raw_data

# %%
h1b_18 = str_to_float('PREVAILING_WAGE', h1b_18)
h1b_18 = str_to_float('WAGE_RATE_OF_PAY_FROM', h1b_18)
h1b_18 = str_to_float('WAGE_RATE_OF_PAY_TO', h1b_18)

# %% [markdown]
# ### combine files together

# %%
frames = [h1b_17, h1b_18]
raw_data = pd.concat(frames, axis=0, sort=False)
print(raw_data.shape)
raw_data.head()
# Out:
# (1279010, 52)
#           CASE_NUMBER          CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  I-200-16055-173457  CERTIFIED-WITHDRAWN     2016-02-24    2016-10-01
# 1  I-200-16064-557834  CERTIFIED-WITHDRAWN     2016-03-04    2016-10-01
# 2  I-200-16063-996093  CERTIFIED-WITHDRAWN     2016-03-10    2016-10-01
# 3  I-200-16272-196340            WITHDRAWN     2016-09-28    2016-10-01
# 4  I-200-15053-636744  CERTIFIED-WITHDRAWN     2015-02-22    2016-10-02
#
#   VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0       H-1B            2016-08-10          2019-08-10
# 1       H-1B            2016-08-16          2019-08-16
# 2       H-1B            2016-09-09          2019-09-09
# 3       H-1B            2017-01-26          2020-01-25
# 4       H-1B            2015-03-01          2018-03-01
#
#                EMPLOYER_NAME EMPLOYER_BUSINESS_DBA  \
# 0     DISCOVER PRODUCTS INC.                   NaN
# 1           DFS SERVICES LLC                   NaN
# 2  EASTBANC TECHNOLOGIES LLC                   NaN
# 3          INFO SERVICES LLC                   NaN
# 4           BB&T CORPORATION                   NaN
#
#              EMPLOYER_ADDRESS  ... H1B_DEPENDENT WILLFUL_VIOLATOR SUPPORT_H1B  \
# 0         2500 LAKE COOK ROAD  ...             N                N         NaN
# 1         2500 LAKE COOK ROAD  ...             N                N         NaN
# 2            1211 31ST ST. NW  ...             Y                N           Y
# 3  17177 NORTH LAUREL PARK DR  ...             Y                N           Y
# 4        223 WEST NASH STREET  ...             N                N         NaN
#
#   LABOR_CON_AGREE PUBLIC_DISCLOSURE_LOCATION WORKSITE_CITY WORKSITE_COUNTY  \
# 0               Y                        NaN    RIVERWOODS            LAKE
# 1               Y                        NaN    RIVERWOODS            LAKE
# 2             NaN                        NaN    WASHINGTON             NaN
# 3             NaN                        NaN   JERSEY CITY          HUDSON
# 4               Y                        NaN      NEW YORK        NEW YORK
#
#   WORKSITE_STATE WORKSITE_POSTAL_CODE ORIGINAL_CERT_DATE
# 0             IL                60015         2016-03-01
# 1             IL                60015         2016-03-08
# 2             DC                20007         2016-03-16
# 3             NJ                07302                NaN
# 4             NY                10036         2015-02-26
#
# [5 rows x 52 columns]

# %%
raw_data.to_csv('h1b.csv', index=False)
